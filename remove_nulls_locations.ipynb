# %%
import mysql.connector

from sqlalchemy import create_engine

# create sqlalchemy engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="jbatista",
                               pw="",
                               db="final_schema"))

# %%
cnx = mysql.connector.connect(user = 'jbatista',
                                password = '',
                                host = '127.0.0.1')

# %%
import pandas as pd
import numpy as np

# %%
cursor = cnx.cursor()

# %%
def read_table(table):
	query = "SELECT * FROM " + table +";"
	cursor.execute(query)

# %%
read_table("final_schema.locations")

# %%
locations = cursor.fetchall()

# %%
locations_df = pd.DataFrame(locations)

# %%
locations_df.columns = cursor.column_names
locations_df
# Out:
#     index     id  country.id    country.name country.abbrev  city.id  \
# 0       0  15901        57.0         Germany             DE  31156.0
# 1       1  16022        29.0          Mexico             MX  31175.0
# 2       2  16086        59.0     Netherlands             NL  31168.0
# 3       3  16088        42.0          Brazil             BR  31121.0
# 4       4  16109        38.0          France             FR  31136.0
# 5       5  16375         1.0   United States             US     31.0
# 6       6  16376        12.0           Spain             ES  31052.0
# 7       7  16377        12.0           Spain             ES  31170.0
# 8       8  16709        28.0        Portugal             PT  31075.0
# 9       9  17233         0.0                                     0.0
# 10     10  15704         1.0   United States             US     13.0
# 11     11  15705         1.0   United States             US   1507.0
# 12     12  15862         0.0                                     0.0
# ...

# %%
type(locations_df["country.id"][0])
# Out:
# numpy.float64

# %%
locations_df["country.id"].fillna(99, inplace=True)

# %%
locations_df
# Out:
#     index     id  country.id    country.name country.abbrev  city.id  \
# 0      10  15704         1.0   United States             US     13.0
# 1      11  15705         1.0   United States             US   1507.0
# 2      12  15862        99.0            None           None      NaN
# 3      15  15899        99.0            None           None      NaN
# 4       0  15901        57.0         Germany             DE  31156.0
# 5      21  15935         1.0   United States             US   1507.0
# 6      22  15985         2.0          Canada             CA   1547.0
# 7      17  16002         1.0   United States             US     10.0
# 8      23  16010         2.0          Canada             CA  31138.0
# 9      13  16013        99.0            None           None      NaN
# 10      1  16022        29.0          Mexico             MX  31175.0
# 11     16  16045         1.0   United States             US     39.0
# 12      2  16086        59.0     Netherlands             NL  31168.0
# ...

# %%
locations_df["country.name"].fillna("Online", inplace=True)

# %%
locations_df["country.abbrev"].fillna("OL", inplace=True)

# %%
locations_df["city.id"].fillna(99, inplace=True)

# %%
locations_df
# Out:
#     index     id  country.id    country.name country.abbrev  city.id  \
# 0       0  15901        57.0         Germany             DE  31156.0
# 1       1  16022        29.0          Mexico             MX  31175.0
# 2       2  16086        59.0     Netherlands             NL  31168.0
# 3       3  16088        42.0          Brazil             BR  31121.0
# 4       4  16109        38.0          France             FR  31136.0
# 5       5  16375         1.0   United States             US     31.0
# 6       6  16376        12.0           Spain             ES  31052.0
# 7       7  16377        12.0           Spain             ES  31170.0
# 8       8  16709        28.0        Portugal             PT  31075.0
# 9       9  17233         0.0                                     0.0
# 10     10  15704         1.0   United States             US     13.0
# 11     11  15705         1.0   United States             US   1507.0
# 12     12  15862         0.0                                     0.0
# ...

# %%
def replace(x):
	if x == 0:
		return 99
	else:
		return x

locations_df["country.id"] = locations_df["country.id"].apply(replace)

# %%
locations_df
# Out:
#     index     id  country.id    country.name country.abbrev  city.id  \
# 0       0  15901        57.0         Germany             DE  31156.0
# 1       1  16022        29.0          Mexico             MX  31175.0
# 2       2  16086        59.0     Netherlands             NL  31168.0
# 3       3  16088        42.0          Brazil             BR  31121.0
# 4       4  16109        38.0          France             FR  31136.0
# 5       5  16375         1.0   United States             US     31.0
# 6       6  16376        12.0           Spain             ES  31052.0
# 7       7  16377        12.0           Spain             ES  31170.0
# 8       8  16709        28.0        Portugal             PT  31075.0
# 9       9  17233        99.0                                     0.0
# 10     10  15704         1.0   United States             US     13.0
# 11     11  15705         1.0   United States             US   1507.0
# 12     12  15862        99.0                                     0.0
# ...

# %%
def cn_replace(x):
	if (x == ""):
		return "Online"
	else:
		return x

locations_df["country.name"] = locations_df["country.name"].apply(cn_replace)

# %%
def cn_replace(x):
	if (x == ""):
		return "online"
	else:
		return x

		
locations_df["country.abbrev"] = locations_df["country.abbrev"].apply(cn_replace)

# %%
locations_df["city.keyword"] = locations_df["city.keyword"].apply(cn_replace)

# %%
locations_df
# Out:
#     index     id  country.id    country.name country.abbrev  city.id  \
# 0       0  15901        57.0         Germany             DE  31156.0
# 1       1  16022        29.0          Mexico             MX  31175.0
# 2       2  16086        59.0     Netherlands             NL  31168.0
# 3       3  16088        42.0          Brazil             BR  31121.0
# 4       4  16109        38.0          France             FR  31136.0
# 5       5  16375         1.0   United States             US     31.0
# 6       6  16376        12.0           Spain             ES  31052.0
# 7       7  16377        12.0           Spain             ES  31170.0
# 8       8  16709        28.0        Portugal             PT  31075.0
# 9       9  17233        99.0          Online         online      0.0
# 10     10  15704         1.0   United States             US     13.0
# 11     11  15705         1.0   United States             US   1507.0
# 12     12  15862        99.0          Online         online      0.0
# ...

# %%
cursor.close()
cnx.close()

# %%
locations_df.to_sql('locations', con = engine, if_exists = 'replace', chunksize = 1000)
# Out:
# 29
