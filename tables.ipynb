# %%
import mysql.connector

from sqlalchemy import create_engine

# create sqlalchemy engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="jbatista",
                               pw="",
                               db="final_schema"))

# %%
cnx = mysql.connector.connect(user = 'jbatista',
                                password = '',
                                host = '127.0.0.1')

# %%
cnx.is_connected()
# Out:
# True

# %%
cursor = cnx.cursor()
cursor

# %%
query = '''SELECT * 
FROM project_data_lake.badges;'''

query
# Out:
# 'SELECT * \nFROM project_data_lake.badges;'

# %%
cursor.execute(query)

# %%
result = cursor.fetchall()
display(result)
# Out:
# [(0,
#   'Available Online',
#   'available_online',
#   '<p>School offers fully online courses</p>',
#   'ironhack',
#   10828),
#  (1,
#   'Verified Outcomes',
#   'verified_outcomes',
#   '<p>School publishes a third-party verified outcomes report</p>',
#   'ironhack',
#   10828),
#  (2,
#   'Flexible Classes',
#   'flexible_classes',
#   '<p>School offers part-time and evening classes</p>',
#   'ironhack',
#   10828),
#  (0,
#   'Available Online',
#   'available_online',
#   '<p>School offers fully online courses</p>',
#   'app-academy',
#   10525),
#  (1,
#   'Flexible Classes',
#   'flexible_classes',
#   '<p>School offers part-time and evening classes</p>',
#   'app-academy',
#   10525),
#  (0,
#   'Available Online',
#   'available_online',
#   '<p>School offers fully online courses</p>',
#   'springboard',
#   11035),
#  (1,
#   'Flexible Classes',
#   'flexible_classes',
#   '<p>School offers part-time and evening classes</p>',
#   'springboard',
#   11035),
#  (2,
# ...

# %%
for element in result:
    badges = (element[2] + ' ' + element[4]+ ' ' + str(element[5]))
    print(badges)
# Out:
# available_online ironhack 10828
# verified_outcomes ironhack 10828
# flexible_classes ironhack 10828
# available_online app-academy 10525
# flexible_classes app-academy 10525
# available_online springboard 11035
# flexible_classes springboard 11035
# job_guarantee springboard 11035
# available_online practicum-coding-bootcamps 11225
# job_guarantee practicum-coding-bootcamps 11225
# available_online evolve-security-academy 10743
# flexible_classes evolve-security-academy 10743
# accepts_gi_bill evolve-security-academy 10743
# available_online codesmith 10643
# verified_outcomes codesmith 10643
# flexible_classes codesmith 10643
# available_online brainstation 10571
# flexible_classes brainstation 10571

# %%
import pandas as pd
column_names = [head[0] for head in cursor.description]
result = pd.DataFrame(result, columns=column_names)
display(result)
# Out:
#     index               name            keyword  \
# 0       0   Available Online   available_online
# 1       1  Verified Outcomes  verified_outcomes
# 2       2   Flexible Classes   flexible_classes
# 3       0   Available Online   available_online
# 4       1   Flexible Classes   flexible_classes
# 5       0   Available Online   available_online
# 6       1   Flexible Classes   flexible_classes
# 7       2      Job Guarantee      job_guarantee
# 8       0   Available Online   available_online
# 9       1      Job Guarantee      job_guarantee
# 10      0   Available Online   available_online
# 11      1   Flexible Classes   flexible_classes
# 12      2    Accepts GI Bill    accepts_gi_bill
# 13      0   Available Online   available_online
# 14      1  Verified Outcomes  verified_outcomes
# 15      2   Flexible Classes   flexible_classes
# 16      0   Available Online   available_online
# 17      1   Flexible Classes   flexible_classes
#
# ...

# %%
result = result.drop(["index",'name','description'], axis=1)

# %%
result
result.reset_index(inplace=True, names="ID")
display(result)
# Out:
#     ID            keyword                      school  school_id
# 0    0   available_online                    ironhack      10828
# 1    1  verified_outcomes                    ironhack      10828
# 2    2   flexible_classes                    ironhack      10828
# 3    3   available_online                 app-academy      10525
# 4    4   flexible_classes                 app-academy      10525
# 5    5   available_online                 springboard      11035
# 6    6   flexible_classes                 springboard      11035
# 7    7      job_guarantee                 springboard      11035
# 8    8   available_online  practicum-coding-bootcamps      11225
# 9    9      job_guarantee  practicum-coding-bootcamps      11225
# 10  10   available_online     evolve-security-academy      10743
# 11  11   flexible_classes     evolve-security-academy      10743
# 12  12    accepts_gi_bill     evolve-security-academy      10743
# ...

# %%
badges = result
badges.to_sql('badges', con = engine, if_exists = 'replace', chunksize = 1000)
# Out:
# 18

# %%
print(badges)
# Out:
#     ID            keyword                      school  school_id
# 0    0   available_online                    ironhack      10828
# 1    1  verified_outcomes                    ironhack      10828
# 2    2   flexible_classes                    ironhack      10828
# 3    3   available_online                 app-academy      10525
# 4    4   flexible_classes                 app-academy      10525
# 5    5   available_online                 springboard      11035
# 6    6   flexible_classes                 springboard      11035
# 7    7      job_guarantee                 springboard      11035
# 8    8   available_online  practicum-coding-bootcamps      11225
# 9    9      job_guarantee  practicum-coding-bootcamps      11225
# 10  10   available_online     evolve-security-academy      10743
# 11  11   flexible_classes     evolve-security-academy      10743
# 12  12    accepts_gi_bill     evolve-security-academy      10743
# ...

# %%
query_courses = '''SELECT * 
FROM project_data_lake.courses;'''

query_courses
# Out:
# 'SELECT * \nFROM project_data_lake.courses;'

# %%
cursor.execute(query_courses)

# %%
courses = cursor.fetchall()
print(courses)
# Out:
# [(0, 'Cyber Security Bootcamp', 'ironhack', 10828), (1, 'Cybersecurity Part-Time', 'ironhack', 10828), (2, 'Data Analytics Bootcamp', 'ironhack', 10828), (3, 'Data Analytics Part-Time', 'ironhack', 10828), (4, 'UX/UI Design Bootcamp', 'ironhack', 10828), (5, 'UX/UI Design Part-Time', 'ironhack', 10828), (6, 'Web Development Bootcamp', 'ironhack', 10828), (7, 'Web Development Part-Time', 'ironhack', 10828), (0, '16-Week Campus Software Engineering Program', 'app-academy', 10525), (1, 'Bootcamp Prep', 'app-academy', 10525), (2, '24-Week Online Full-Time Software Engineering Program', 'app-academy', 10525), (3, '52-Week Online Part-Time Software Engineering', 'app-academy', 10525), (4, 'App Academy Open', 'app-academy', 10525), (0, 'Cyber Security Career Track', 'springboard', 11035), (1, 'Data Analytics Career Track', 'springboard', 11035), (2, 'Data Science Career Track', 'springboard', 11035), (3, 'Data Science Career Track Prep', 'springboard', 11035), (4, 'Digital Marketing Profess
# ...

# %%
courses_df = pd.DataFrame(courses)

# %%
display(courses_df)
# Out:
#      0                                                  1  \
# 0    0                            Cyber Security Bootcamp
# 1    1                            Cybersecurity Part-Time
# 2    2                            Data Analytics Bootcamp
# 3    3                           Data Analytics Part-Time
# 4    4                              UX/UI Design Bootcamp
# 5    5                             UX/UI Design Part-Time
# 6    6                           Web Development Bootcamp
# 7    7                          Web Development Part-Time
# 8    0        16-Week Campus Software Engineering Program
# 9    1                                      Bootcamp Prep
# 10   2  24-Week Online Full-Time Software Engineering ...
# 11   3      52-Week Online Part-Time Software Engineering
# 12   4                                   App Academy Open
# 13   0                        Cyber Security Career Track
# 14   1                        Data Analytics Career Track
# ...

# %%
cursor.close()
cnx.close()
